# %%
import torch
import numpy as np
from torch import nn
import torchvision
from torchvision import transforms, datasets
from torch import optim
from torch.utils.data.sampler import SubsetRandomSampler

# %%
from matplotlib import pyplot as plt

# %%
import torch.nn.functional as F

# %%
transform = transforms.Compose([transforms.ToTensor()])

# %%
trainset= datasets.MNIST('~/.pytorch/MNIST/', train=True, download=True, transform=transform)

validset= datasets.MNIST('~/.pytorch/MNIST/', train=True, download=True, transform=transform)

testset= datasets.MNIST('~/.pytorch/MNIST/', train=False, download=True,transform=transform)

# %%
batch_size = 100
pin_memory = 1
num_workers = 1

# %%
# train_loader = torch.utils.data.DataLoader(
#     trainset, batch_size=batch_size,
#     num_workers=num_workers, pin_memory=pin_memory,
# )

# %%
num_train = len(trainset)
num_test = len(testset)
indices = list(range(num_train))
split = int(np.floor(0.3 * num_train))

np.random.seed(42)
np.random.shuffle(indices)

# %%
train_idx, valid_idx = indices[split:], indices[:split]
train_sampler = SubsetRandomSampler(train_idx)
valid_sampler = SubsetRandomSampler(valid_idx)
train_loader = torch.utils.data.DataLoader(
    trainset, batch_size=batch_size, sampler=train_sampler,
    num_workers=num_workers, pin_memory=pin_memory,
)
valid_loader = torch.utils.data.DataLoader(
    validset, batch_size=batch_size, sampler=valid_sampler,
    num_workers=num_workers, pin_memory=pin_memory,
)

test_loader = torch.utils.data.DataLoader(
    testset, batch_size=batch_size, num_workers=num_workers, 
    pin_memory=pin_memory, shuffle=True
)

# %%
for imgs,labels in train_loader:
    print(imgs.shape,labels.shape)
    break
# Out:
# torch.Size([100, 1, 28, 28]) torch.Size([100])

# %%
class AutoEncoder(nn.Module):
    def __init__(self):
        super().__init__()
        self.cnn1 = nn.Conv2d(1,2,kernel_size=3,padding=1)
        self.cnn2 = nn.Conv2d(2,4,kernel_size=3,padding=1)
        self.cnn3 = nn.Conv2d(4,8,kernel_size=3,padding=1)

        self.pool = nn.MaxPool2d(2,return_indices=True)
        
        self.unpool = nn.MaxUnpool2d(2)
        
        self.t_cnn1 = nn.ConvTranspose2d(8,4,kernel_size=3,padding=1)
        self.t_cnn2 = nn.ConvTranspose2d(4,2,kernel_size=3,padding=1)
        self.t_cnn3 = nn.ConvTranspose2d(2,1,kernel_size=3,padding=1)
        
    def forward(self,x):
        out = F.relu(self.cnn1(x))
        out,ind1 = self.pool(out)
        
        out = F.relu(self.cnn2(out))
        out,ind2 = self.pool(out)

        out = self.cnn3(out)
        
        out = F.relu(self.t_cnn1(out))
        out = self.unpool(out,ind2)

        out = F.relu(self.t_cnn2(out))
        out = self.unpool(out,ind1)

        out = F.sigmoid(self.t_cnn3(out))
        
        return out

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
model = AutoEncoder().to(device)

# %%
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(),lr= 0.0001,weight_decay=1e-5)
# steps = 10
scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=[25,30],gamma=0.1)

# %%
epochs = 35
iter_n = 0
iter_total = 0
stats_list = list()

# %%
for e in range(epochs):
    iter_n = 0
    print("Epoch %d of %d"%(e+1,epochs))
    inputs = list()
    outputs = list()
    for imgs,_ in train_loader:
        
        imgs = imgs.to(device)
        optimizer.zero_grad()
        recons = model(imgs)
        
        inputs.append(imgs[0].cpu().data)
        outputs.append(recons[0].cpu().data)
        
        loss = criterion(recons,imgs)
        loss.backward()
        optimizer.step()
    scheduler.step()
    print('Epoch {}. Loss: {:4f}'.format(e+1,float(loss)))
# Out:
# Epoch 1 of 35
# /home/varunc/env/lib/python3.7/site-packages/torch/nn/functional.py:1569: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# Epoch 1. Loss: 0.141877
# Epoch 2 of 35
# Epoch 2. Loss: 0.106072
# Epoch 3 of 35
# Epoch 3. Loss: 0.086511
# Epoch 4 of 35
# Epoch 4. Loss: 0.065853
# Epoch 5 of 35
# Epoch 5. Loss: 0.064041
# Epoch 6 of 35
# Epoch 6. Loss: 0.055373
# Epoch 7 of 35
# Epoch 7. Loss: 0.053659
# Epoch 8 of 35
# Epoch 8. Loss: 0.049250
# Epoch 9 of 35
# Epoch 9. Loss: 0.046506
# Epoch 10 of 35
# Epoch 10. Loss: 0.042181
# Epoch 11 of 35
# Epoch 11. Loss: 0.041959
# Epoch 12 of 35
# Epoch 12. Loss: 0.039847
# Epoch 13 of 35
# Epoch 13. Loss: 0.036596
# Epoch 14 of 35
# Epoch 14. Loss: 0.035203
# Epoch 15 of 35
# Epoch 15. Loss: 0.037579
# Epoch 16 of 35
# Epoch 16. Loss: 0.037040
# Epoch 17 of 35
# Epoch 17. Loss: 0.034882
# Epoch 18 of 35
# Epoch 18. Loss: 0.031654
# Epoch 19 of 35
# Epoch 19. Loss: 0.031513
# Epoch 20 of 35
# Epoch 20. Loss: 0.030015
# Epoch 21 of 35
# Epoch 21. Loss: 0.028040
# Epoch 22 of 35
# Epoch 22. Loss: 0.029623
# Epoch 23 of 35
# Epoch 23. Loss: 0.025836
# Epoch 24 of 35
# Epoch 24. Loss: 0.026921
# Epoch 25 of 35
# Epoch 25. Loss: 0.025903
# Epoch 26 of 35
# Epoch 26. Loss: 0.024203
# Epoch 27 of 35
# Epoch 27. Loss: 0.026046
# Epoch 28 of 35
# Epoch 28. Loss: 0.025037
# Epoch 29 of 35
# Epoch 29. Loss: 0.026136
# Epoch 30 of 35
# Epoch 30. Loss: 0.025674
# Epoch 31 of 35
# Epoch 31. Loss: 0.024178
# Epoch 32 of 35
# Epoch 32. Loss: 0.026080
# Epoch 33 of 35
# Epoch 33. Loss: 0.024512
# Epoch 34 of 35
# Epoch 34. Loss: 0.024720
# Epoch 35 of 35
# Epoch 35. Loss: 0.024964

# %%
for e in range(epochs):
    print("Epoch {}".format(e+1))
    plt.imshow(inputs[e].numpy()[0])
    plt.show()
    plt.imshow(outputs[e].numpy()[0])
    plt.show()
# Out:
# Epoch 1
# Epoch 2
# Epoch 3
# Epoch 4
# Epoch 5
# Epoch 6
# Epoch 7
# Epoch 8
# Epoch 9
# Epoch 10
# Epoch 11
# Epoch 12
# Epoch 13
# Epoch 14
# Epoch 15
# Epoch 16
# Epoch 17
# Epoch 18
# Epoch 19
# Epoch 20
# Epoch 21
# Epoch 22
# Epoch 23
# Epoch 24
# Epoch 25
# Epoch 26
# Epoch 27
# Epoch 28
# Epoch 29
# Epoch 30
# Epoch 31
# Epoch 32
# Epoch 33
# Epoch 34
# Epoch 35
